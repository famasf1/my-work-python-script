# %%
import os
import openpyxl
from tkinter import Tk, filedialog

# %%
asset_directory = r"D:\Workstuff\my-work-python-script\project_bebephone\Asset"

root = Tk()

# %%
#get asset
asset_dir = os.path.join(asset_directory, r"BARCODE.xlsx")
PRINT_dir = r"D:\Workstuff\my-work-python-script\project_bebephone\PRINT"
workbook = openpyxl.load_workbook(asset_dir, data_only=True)
worksheet = workbook.sheetnames
block90_sheet = workbook[worksheet[0]]
block117_sheet = workbook[worksheet[1]]
block56_sheet = workbook[worksheet[2]]
#get data
get_wb = filedialog.askopenfilename(title="เลือกไฟล์ข้อมูล Excel", filetypes=([("*Excel Files", "*.xlsx"), ("All Files", "*.*")]))
data_wb = openpyxl.load_workbook(get_wb, data_only=True)
data_sheet = data_wb.sheetnames
get_sheet = data_wb[data_sheet[0]]

# %% [markdown]
# <h1>BLOCK56</H1>

# %%
asset_dir_56 = os.path.join(asset_directory, r"block56template.xlsm")
block56_wb = openpyxl.load_workbook(asset_dir_56, data_only=True, keep_vba=True)
block56_ws = block56_wb.sheetnames
block56 = block56_wb[block56_ws[0]]

# %% [markdown]
# <h1>BLOCK 117</h1>

# %% [markdown]
# <h1>BLOCK117</h1>

# %%
asset_dir_117 = os.path.join(asset_directory, r"block117template.xlsm")
block117_wb = openpyxl.load_workbook(asset_dir_117, data_only=True, keep_vba=True)
block117_ws = block117_wb.sheetnames
block117 = block117_wb[block117_ws[0]]

# %%
#bebe row
bebe_start_row_number = 2

#barcode row
com7barcode_startrow = 3

#barcode text
com7barcodetext_startrow = 4

#data
data_startrow = 3

ran = False
col = 2

# %%
for total_print_row in range(2, get_sheet.max_row + 1):
    bebecode = get_sheet.cell(row=total_print_row,column = 2).value #0166
    com7productcode = get_sheet.cell(row=total_print_row, column = 1).value #51691
    total_sticker = get_sheet.cell(row=total_print_row, column=3).value
    total_print_data = get_sheet.cell(row=total_print_row, column = 4).value #8 #int

    for beberow in range(bebe_start_row_number, 74, 4):
        for col in range(2,17,3):
            block90.cell(row=beberow, column=col).value = bebecode
    
    for com7barcoderow in range(com7barcode_startrow, 75, 4):
        for col in range(2,17,3):
            block90.cell(row=com7barcoderow, column=col).value = f'''=code128("{com7productcode}")'''
    
    for com7barcodetext_row in range(com7barcodetext_startrow, 76, 4):
        for col in range(2,17,3):
            block90.cell(row=com7barcodetext_row, column=col).value = com7productcode

    
    print(os.getcwd())
    block90_wb.save("test.xlsm")
    break
# Out:
# c:\Users\jambo\OneDrive\เดสก์ท็อป\Workspaces\my-work-python-script\project_bebephone

# %%
for total_print_row in range(3,get_sheet.max_row+1):
    
    bebecode = get_sheet.cell(row=total_print_row,column = 2).value #0166
    com7productcode = get_sheet.cell(row=total_print_row, column = 1).value #51691
    total_sticker = get_sheet.cell(row=total_print_row, column=3).value
    total_print_data = get_sheet.cell(row=total_print_row, column = 4).value #8 #int
    print(bebecode)
    print(total_print_row)
    if total_sticker > 1:
        os.chdir(r"D:\Workstuff\my-work-python-script\project_bebephone\ปริ้น 2 แผ่น")
        #b
        block90['B2'] = bebecode
        block90['B3'] = com7productcode
        block90['B4'] = com7productcode
        #e
        block90['E2'] = bebecode
        block90['E3'] = com7productcode
        block90['E4'] = com7productcode
        #h
        block90['H2'] = bebecode
        block90['H3'] = com7productcode
        block90['H4'] = com7productcode
        #k
        block90['K2'] = bebecode
        block90['K3'] = com7productcode
        block90['K4'] = com7productcode
        #n
        block90['N2'] = bebecode
        block90['N3'] = com7productcode
        block90['N4'] = com7productcode
# Out:
# 51691
# 3
# 87026
# 4
# 87037
# 5

# %%
asset_dir_127 = os.path.join(asset_directory, r"block117template.xlsx")
block117_wb = openpyxl.load_workbook(asset_dir_117, data_only=True)
block117_ws = block117_wb.sheetnames
block117 = block117_wb[block117_ws[0]]
new_dir = os.path.join(os.getcwd(), "excel")

total_print_list = [] #must under 56


for total_print_row in range(2,get_sheet.max_row+1):
    
    bebecode = get_sheet.cell(row=total_print_row,column = 1).value #0166
    com7productcode = get_sheet.cell(row=total_print_row, column = 2).value #51691
    total_print_data = get_sheet.cell(row=total_print_row, column = 5).value #8 #int


    #define row
    #block56
    
    #create list to determine whether it hits 56
    total_print_list.append(total_print_data)
    print(total_print_list)


    for row_cell in range(1,total_print_data+1):

        print(f"loop : {row_cell}")
        for bebe_row in range(bebe_start_row_number,74,4):
            for com7barcoderow in range(com7barcode_startrow, 75, 4):
                for com7barcodetext_row in range(com7barcodetext_startrow, 76, 4):
                    if col == 17:
                        print(bebe_row)
                        print(com7barcoderow)
                        print(com7barcodetext_row)
                        print(col)
                        col = 2
                        bebe_start_row_number = bebe_row + 4
                        com7barcode_startrow = com7barcoderow + 4
                        com7barcodetext_startrow = com7barcodetext_row + 4
                        break
                    else:                            
                        block117.cell(row=bebe_row, column=col).value = bebecode
                        block117.cell(row=com7barcoderow, column=col).value = com7productcode
                        block117.cell(row=com7barcodetext_row, column=col).value = com7productcode
                        print(bebe_row)
                        print(com7barcoderow)
                        print(com7barcodetext_row)
                        print(col)
                        col += 3
                        break
                    break
                break
            break   
        if sum(total_print_list) >= 117:
            print(total_print_list)
            block117_wb.save(os.path.join(new_dir,f"test{row_cell}.xlsx"))
        else:
            break
# Out:
# [9]
# loop : 1
# 2
# 3
# 4
# 2
# [9, 27]
# loop : 1
# 2
# 3
# 4
# 5
# [9, 27, 9]
# loop : 1
# 2
# 3
# 4
# 8
# [9, 27, 9, 9]
# loop : 1
# 2
# 3
# 4
# 11
# [9, 27, 9, 9, 36]
# loop : 1
# 2
# 3
# 4
# 14
# [9, 27, 9, 9, 36, 9]
# loop : 1
# 2
# 3
# 4
# 17
# [9, 27, 9, 9, 36, 9, 9]
# loop : 1
# 6
# 7
# 8
# 2
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 1
# 6
# 7
# 8
# 5
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 2
# 6
# 7
# 8
# 8
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 3
# 6
# 7
# 8
# 11
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 4
# 6
# 7
# 8
# 14
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 5
# 6
# 7
# 8
# 17
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 6
# 10
# 11
# 12
# 2
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 7
# 10
# 11
# 12
# 5
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 8
# 10
# 11
# 12
# 8
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 9
# 10
# 11
# 12
# 11
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 10
# 10
# 11
# 12
# 14
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 11
# 10
# 11
# 12
# 17
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 12
# 14
# 15
# 16
# 2
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 13
# 14
# 15
# 16
# 5
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 14
# 14
# 15
# 16
# 8
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 15
# 14
# 15
# 16
# 11
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 16
# 14
# 15
# 16
# 14
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 17
# 14
# 15
# 16
# 17
# [9, 27, 9, 9, 36, 9, 9, 18]
# loop : 18
# 18
# 19
# 20
# 2
# [9, 27, 9, 9, 36, 9, 9, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 1
# 18
# 19
# 20
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 2
# 18
# 19
# 20
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 3
# 18
# 19
# 20
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 4
# 18
# 19
# 20
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 5
# 18
# 19
# 20
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 6
# 22
# 23
# 24
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 7
# 22
# 23
# 24
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 8
# 22
# 23
# 24
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# loop : 9
# 22
# 23
# 24
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 1
# 22
# 23
# 24
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 2
# 22
# 23
# 24
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 3
# 26
# 27
# 28
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 4
# 26
# 27
# 28
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 5
# 26
# 27
# 28
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 6
# 26
# 27
# 28
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 7
# 26
# 27
# 28
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 8
# 26
# 27
# 28
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 9
# 30
# 31
# 32
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 10
# 30
# 31
# 32
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 11
# 30
# 31
# 32
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 12
# 30
# 31
# 32
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 13
# 30
# 31
# 32
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 14
# 30
# 31
# 32
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 15
# 34
# 35
# 36
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 16
# 34
# 35
# 36
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 17
# 34
# 35
# 36
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# loop : 18
# 34
# 35
# 36
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 1
# 34
# 35
# 36
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 2
# 34
# 35
# 36
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 3
# 38
# 39
# 40
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 4
# 38
# 39
# 40
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 5
# 38
# 39
# 40
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 6
# 38
# 39
# 40
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 7
# 38
# 39
# 40
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 8
# 38
# 39
# 40
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 9
# 42
# 43
# 44
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 10
# 42
# 43
# 44
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 11
# 42
# 43
# 44
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 12
# 42
# 43
# 44
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 13
# 42
# 43
# 44
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 14
# 42
# 43
# 44
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 15
# 46
# 47
# 48
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 16
# 46
# 47
# 48
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 17
# 46
# 47
# 48
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# loop : 18
# 46
# 47
# 48
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 1
# 46
# 47
# 48
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 2
# 46
# 47
# 48
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 3
# 50
# 51
# 52
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 4
# 50
# 51
# 52
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 5
# 50
# 51
# 52
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 6
# 50
# 51
# 52
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 7
# 50
# 51
# 52
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 8
# 50
# 51
# 52
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# loop : 9
# 54
# 55
# 56
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 1
# 54
# 55
# 56
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 2
# 54
# 55
# 56
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 3
# 54
# 55
# 56
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 4
# 54
# 55
# 56
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 5
# 54
# 55
# 56
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 6
# 58
# 59
# 60
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 7
# 58
# 59
# 60
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 8
# 58
# 59
# 60
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 9
# 58
# 59
# 60
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 10
# 58
# 59
# 60
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 11
# 58
# 59
# 60
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 12
# 62
# 63
# 64
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 13
# 62
# 63
# 64
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 14
# 62
# 63
# 64
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 15
# 62
# 63
# 64
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 16
# 62
# 63
# 64
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 17
# 62
# 63
# 64
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# loop : 18
# 66
# 67
# 68
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 1
# 66
# 67
# 68
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 2
# 66
# 67
# 68
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 3
# 66
# 67
# 68
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 4
# 66
# 67
# 68
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 5
# 66
# 67
# 68
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 6
# 70
# 71
# 72
# 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 7
# 70
# 71
# 72
# 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 8
# 70
# 71
# 72
# 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# loop : 9
# 70
# 71
# 72
# 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 1
# 70
# 71
# 72
# 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 2
# 70
# 71
# 72
# 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 19
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 20
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 21
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 22
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 23
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 24
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 25
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 26
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# loop : 27
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 19
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 20
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 21
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 22
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 23
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 24
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 25
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 26
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# loop : 27
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 19
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 20
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 21
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 22
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 23
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 24
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 25
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 26
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# loop : 27
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 10
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 11
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 12
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 13
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 14
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 15
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 16
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 17
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 18
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 19
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 20
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 21
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 22
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 23
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 24
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 25
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 26
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# loop : 27
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 3
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 4
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 5
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 6
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 7
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 8
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# loop : 9
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9]
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9, 9]
# loop : 1
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9, 9]
# loop : 2
# [9, 27, 9, 9, 36, 9, 9, 18, 9, 18, 18, 9, 18, 9, 9, 9, 9, 9, 9, 9, 27, 9, 9, 9, 9, 9, 27, 27, 18, 18, 27, 9, 9, 9, 9, 9, 9]
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Comseven\AppData\Local\Temp\ipykernel_16004\3385182803.py", line 56, in <cell line: 10>
#     block117_wb.save(os.path.join(new_dir,f"test{row_cell}.xlsx"))
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\workbook.py", line 407, in save
#     save_workbook(self, filename)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py", line 293, in save_workbook
#     writer.save()
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py", line 275, in save
#     self.write_data()
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py", line 75, in write_data
#     self._write_worksheets()
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py", line 215, in _write_worksheets
#     self.write_worksheet(ws)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py", line 200, in write_worksheet
#     writer.write()
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_writer.py", line 359, in write
#     self.write_rows()
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_writer.py", line 125, in write_rows
#     self.write_row(xf, row, row_idx)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_writer.py", line 133, in write_row
#     attrs.update(dims.get(row_idx, {}))
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\dimensions.py", line -1, in __iter__
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 699, in lines
#     pieces = self.included_pieces
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 647, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\stack_data\core.py", line 626, in executing_piece
#     return only(
#   File "c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
def generate_barcode(data = '0'):
    #get asset
    asset_dir = os.path.join(asset_directory, r"BARCODE.xlsx")
    PRINT_dir = r"D:\Workstuff\my-work-python-script\project_bebephone\PRINT"
    workbook = openpyxl.load_workbook(asset_dir, data_only=True)
    worksheet = workbook.sheetnames
    block90_sheet = workbook[worksheet[0]]
    block117_sheet = workbook[worksheet[1]]
    block56_sheet = workbook[worksheet[2]]
    #get data
    get_wb = filedialog.askopenfilename(title="เลือกไฟล์ข้อมูล Excel", filetypes=([("*Excel Files", "*.xlsx"), ("All Files", "*.*")]))
    data_wb = openpyxl.load_workbook(get_wb, data_only=True)
    data_sheet = data_wb.sheetnames
    get_sheet = data_wb[data_sheet[0]]

    #loop create folder
    #TODO

    ####for folder_dir in range(3,141,2):
    ####    folder_name = str(get_sheet.cell(row=2, column=folder_dir).value)
    ####    os.mkdir(os.path.join(PRINT_dir,folder_name))

    #loop data
    #beberow

    #this loop get just data to calculate
    total_print_list = []
    for total_print_row in range(3,get_sheet.max_row+1):
        bebecode = get_sheet.cell(row=total_print_row,column=2).value
        com7productcode = get_sheet.cell(row=total_print_row, column = 1).value
        total_print_data = get_sheet.cell(row=total_print_row, column = 4).value #int

        total_print_list.append(total_print_data)
        for row_cell in range(1,total_print_data):
            #total_print_list = [].append(total_print)
            #            print(total_print_list)
            #            if sum(total_print_list) == 56:
            #                total_print_list = []
            #                print("full")

            def block_56():
                #bebecode row
                for bebe_row in range(3,73,5):
                    for bebe_col in range(2,10,2):
                        block56_sheet.cell(row=bebe_row, column=bebe_col).value = bebecode
                #barcode row
                for barcode_row in range(4,74,5):
                    for barcode_col in range(2,10,2):
                        block56_sheet.cell(row=barcode_row, column=barcode_col).value = com7productcode
                #barcode number row
                for barcode_number_row in range(5,75,5):
                    for barcode_number_col in range(2,10,2):
                        block56_sheet.cell(row=barcode_number_row, column=barcode_number_row).value = com7productcode
            block_56()
            workbook.save(f"ID:1832-{total_print_row - 2}.xlsx")
                



            #TODO
            def block_90():
                for row2 in range(2,74,4):
                    for colnum2 in range(2,15,3):
                        pass
                    #barcoderow
                    for row3 in range(3,74,4):
                        for colnum3 in range(2,15,3):
                            pass
                    #barcode number row
                    for row4 in range(4,74,4):
                        for colnum4 in range(2,15,3):
                            pass
                            #print(block90_sheet.cell(row=row4, column=colnum4).value)




        if sum(total_print_list) >= 56:
            total_print_list.clear()

# %%
generate_barcode()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Workstuff\my-work-python-script\project_bebephone\test.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> generate_barcode()
#
# d:\Workstuff\my-work-python-script\project_bebephone\test.ipynb Cell 5 in generate_barcode(data)
#      <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=52'>53</a>             block56_sheet.cell(row=barcode_number_row, column=barcode_number_row).value = com7productcode
#      <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=53'>54</a> block_56()
# ---> <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=54'>55</a> workbook.save(f"ID:1832-{total_print_row - 2}.xlsx")
#      <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=59'>60</a> #TODO
#      <a href='vscode-notebook-cell:/d%3A/Workstuff/my-work-python-script/project_bebephone/test.ipynb#W3sZmlsZQ%3D%3D?line=60'>61</a> def block_90():
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py:293, in save_workbook(workbook, filename)
#     291 archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292 writer = ExcelWriter(workbook, archive)
# --> 293 writer.save()
#     294 return True
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py:75, in ExcelWriter.write_data(self)
#      72 else:
#      73     archive.writestr(ARC_THEME, theme_xml)
# ---> 75 self._write_worksheets()
#      76 self._write_chartsheets()
#      77 self._write_images()
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File c:\Users\Comseven\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\writer\excel.py:203, in ExcelWriter.write_worksheet(self, ws)
#     200     writer.write()
#     202 ws._rels = writer._rels
# --> 203 self._archive.write(writer.out, ws.path[1:])
#     204 self.manifest.append(ws)
#     205 writer.cleanup()
#
# File ~\AppData\Local\Programs\Python\Python310\Lib\zipfile.py:1773, in ZipFile.write(self, filename, arcname, compress_type, compresslevel)
#    1771         self.start_dir = self.fp.tell()
#    1772 else:
# -> 1773     with open(filename, "rb") as src, self.open(zinfo, 'w') as dest:
#    1774         shutil.copyfileobj(src, dest, 1024*8)
#
# File ~\AppData\Local\Programs\Python\Python310\Lib\zipfile.py:1149, in _ZipWriteFile.close(self)
#    1147 # Flush any data from the compressor, and update header info
#    1148 if self._compressor:
# -> 1149     buf = self._compressor.flush()
#    1150     self._compress_size += len(buf)
#    1151     self._fileobj.write(buf)
#
# KeyboardInterrupt:
