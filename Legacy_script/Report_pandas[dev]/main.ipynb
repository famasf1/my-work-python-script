# %%
import pandas as pd
import matplotlib as ml

# %%
data_sheet = pd.read_excel(rf"D:\Workstuff\my-work-python-script\Report_pandas[dev]\Data\data.xlsx",)
data_sheet2 = pd.read_excel(rf"D:\Workstuff\my-work-python-script\Report_pandas[dev]\Data\data.xlsx",sheet_name=1)

# %%
sheet
# Out:
#        Product Code                                       Product Name Serial  \
# 0     4894465541767  ITSKINS Casing for iPad Pro 11 inch (2021) Hyb...    NaN
# 1     8859095838102  The Pixel Tempered Glass Film for Apple iPhone...    NaN
# 2     8859095838393  The Pixel Tempered Glass Film for Apple iPhone...    NaN
# 3     8859095838485  The Pixel Tempered Super Glass Film for Apple ...    NaN
# 4     8859095838492  The Pixel Tempered Super Glass Film for Apple ...    NaN
# ...             ...                                                ...    ...
# 8343  8859703403470  Bright Film for Smartphone Samsung Galaxy Tab ...    NaN
# 8344  8859703403470  Bright Film for Smartphone Samsung Galaxy Tab ...    NaN
# 8345  8859703403470  Bright Film for Smartphone Samsung Galaxy Tab ...    NaN
# 8346  8859703403470  Bright Film for Smartphone Samsung Galaxy Tab ...    NaN
# 8347  8857874242386         Blue Box Power Bank 10000 mAh / PD20 Black    NaN
#
# ...

# %%
# Out:
#       Doc No  Branch (ID)                          Branch (Name)  \
# 0      65847           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 1      65847           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 2      65847           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 3      65847           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 4      65847           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# ...      ...          ...                                    ...
# 1265   65922           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 1266   65922           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 1267   65922           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 1268   65922           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
# 1269   65922           49  ID49 : สินค้าโยกเข้าคลัง (01/10/2008)
#
#      Product (Code)                                     Product (Name)  \
# 0     4895199106499  Monocozzi Casing for MacBook Air 13 inch (2020...
# ...
