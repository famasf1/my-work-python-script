# %%
import pandas as pd
import openpyxl as pyxl
import tkinter as tk
from tkinter.filedialog import askopenfilename

# %%
import glob

# %% [markdown]
# <h1>COMBINE EXCEL SHEET INTO 1</h1>

# %%
path = r"C:\Users\Comseven\Documents\DHL\Completed"

file_list = glob.glob(path + "/*.xlsx")
excl_list = []
for file in file_list:
    excl_list.append(pd.read_excel(file))

excl_merge = pd.DataFrame()

for excl_file in excl_list:
    excl_merge = excl_merge.append(excl_file, ignore_index=True)

excl_merge.to_excel(r"C:\Users\Comseven\Documents\DHL\Completed\DHL_ALL_8+9+10.xlsx", index=False)
# Out:
# C:\Users\Comseven\AppData\Local\Temp\ipykernel_20008\3848462476.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   excl_merge = excl_merge.append(excl_file, ignore_index=True)

# %% [markdown]
# <h1>LEGACY -- ALREADY MERGE WITH dhl_files.py -- </h1>

# %%
root = tk.Tk()
root.excel = pd.read_excel(askopenfilename(title="เลือกไฟล์ Excel",filetypes=(('Excel Files' , '*.xlsx'),('All Files','*.*'))))
root.withdraw()
# Out:
# ''

# %%
data = root.excel

# %%
CCN = pd.Series(data['CCN'])
CCN_Insure = data[data["CCN"].str.contains(r"(^PHYIDINSURE.*)-(33-1)$",regex=True, na=False)]
remove_word = CCN_Insure['CCN'].replace(['PHYIDINSURE'],'', regex=True).str.split('-')
df_remove = pd.DataFrame(remove_word)
df_remove_as_table = df_remove[['ID','Branch','Box Num']] = pd.DataFrame(df_remove.CCN.to_list(), index=df_remove.index)
# Out:
# C:\Users\Comseven\AppData\Local\Temp\ipykernel_20008\3695323742.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   CCN_Insure = data[data["CCN"].str.contains(r"(^PHYIDINSURE.*)-(33-1)$",regex=True, na=False)]

# %%
CCN_Insure
# Out:
#       SoldToCustomer  pickupcustomernumber  \
# 0         5267695565            5267695565
# 1         5267695565            5267695565
# 2         5267695565            5267695565
# 3         5267695565            5267695565
# 4         5267695565            5267695565
# ...              ...                   ...
# 1825      5267695565            5267695565
# 1826      5267695565            5267695565
# 1827      5267695565            5267695565
# 1828      5267695565            5267695565
# 1829      5267695565            5267695565
#
#                                           merchant_name       dhlParcelId  \
# 0     Com7 Public Company Limited (C/O : Com7 Shop t...  7223092095115192
# 1     Com7 Public Company Limited (C/O : Com7 Shop t...  7223092416898192
# 2     Com7 Public Company Limited (C/O : Com7 Shop t...  7223093207427292
# 3     Com7 Public Company Limited (C/O : Com7 Shop t...  7223093468184592
# ...

# %%
frames = [CCN_Insure, df_remove_as_table]
complete_frame = pd.concat(frames, axis=1)

# %%
complete_frame.to_excel(r"C:\Users\Comseven\Documents\DHL\Completed\DHL_8+9+10_INSURE_ONLY.xlsx", index=False)
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
